# %%
#workspace();

# %%
#include("poly_helper.jl")
#include("VerificationFunction.jl")

#num_points=2
#cont_order = 3;
#prob = random_poly_prob(num_points,cont_order);                                                                                     
#params = PolyParams(cont_order);
#sol = poly_smoothing(prob, params) 
#plot_poly(sol,1);
#plot_poly_dim(sol,2,"x")
#plot_poly_dim(sol,3,"y")

#Max Velocity and Acceleration taken from what is used in pikachu launch files
#Max Jerk guessed
#verifyActuateablePath(sol, 2.0, 0.65, 2.0, 100000000000000.0);

# %%
include("test.jl")
q_coeff = zeros(7); #This needs the degree of the polynomial to be fit which is 7 in this case
q_coeff[1] = 0.0;
q_coeff[2] = 0.0;
q_coeff[3] = 1.0;
q_coeff[4] = 0.0;
#connect_points([Point(0.0,0.0,0.0,0.0);Point(0.0,0.0,0.0,0.0);Point(0.0,0.0,0.0,0.0)], 
#[Point(1.0,1.0,1.0,0.0);Point(0.0,0.0,0.0,0.0);Point(0.0,0.0,0.0,0.0)], q_coeff);
    test_tester();
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000290E9630>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002912E6A0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000291BFE48>)
# Finished the polynomial connnection
# Cost: 50028.41468253975
# All initial configs good to within precision? If not, a Fail will appear here.
# WARNING: Method definition (::Type{Main.PolyProblem})(Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Int64, 1}, Array{Int64, 1}, Array{Float64, 1}, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:5 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:5.
# WARNING: Method definition (::Type{Main.PolyProblem})(Any, Any, Any, Any, Any, Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:5 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:5.
# WARNING: Method definition (::Type{Main.PolyParams})(Int64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:17 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:17.
# WARNING: Method definition (::Type{Main.PolyParams})(Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:17 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:17.
# WARNING: Method definition (::Type{Main.PolySol})(Main.PolyProblem, Main.PolyParams, Int64, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:21 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:21.
# WARNING: Method definition (::Type{Main.PolySol})(Any, Any, Any, Any, Any, Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:21 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:21.
# WARNING: Method definition (::Type{Main.Point})(Float64, Float64, Float64, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:35 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:35.
# WARNING: Method definition (::Type{Main.Point})(Any, Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:35 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:35.
# WARNING: Method definition (::Type{Main.poly_segment})(Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Float64, Float64, Array{Int64, 1}, Array{Main.Point, 1}, Array{Main.Point, 1}) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:43 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:43.
# WARNING: Method definition (::Type{Main.poly_segment})(Any, Any, Any, Any, Any, Any, Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:43 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:43.
# WARNING: Method definition random_poly_prob(Int64, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:59 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:59.
# WARNING: Method definition print_poly_prob(Main.PolyProblem) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:103 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:103.
# WARNING: Method definition plot_poly_dim(Main.PolySol, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:117 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:117.
# WARNING: Method definition plot_poly(Main.PolySol, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:203 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:203.
# WARNING: Method definition form_Q(Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:282 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:282.
# WARNING: Method definition constr_order(Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:308 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:308.
# WARNING: Method definition form_Abig(Main.PolyProblem, Main.PolyParams, Array{Float64, 1}) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:331 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:331.
# WARNING: Method definition form_Qbig(Any, Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:456 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:456.
# WARNING: Method definition poly_smoothing(Main.PolyProblem, Main.PolyParams) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:627 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:627.
# WARNING: Method definition time_multiseg() in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:691 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:691.
# WARNING: Method definition test_multiseg(Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:718 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:718.
# WARNING: Method definition evaluate_poly(Array{Float64, 1}, Int64, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:738 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:738.
# WARNING: Method definition verifyActuateablePath(Main.PolySol, Float64, Float64, Float64, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:775 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:775.
# WARNING: Method definition occupancyCellChecker(Main.PolySol, Float64, Float64, Float64, Int64, Float64, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:966 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:966.
# WARNING: Method definition connect_points(Array{Main.Point, 1}, Array{Main.Point, 1}, Array{Float64, 1}, Float64, Int64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:1121 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:1121.
# WARNING: Method definition get_grid_extent() in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:26 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:26.
# WARNING: Method definition get_grid_resolution() in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:29 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:29.
# WARNING: Method definition occupancy_check(Float64, Float64, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:34 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:34.
# WARNING: Method definition occupancy_check(Int64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:40 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:40.
# WARNING: Method definition occupancy_get_id(Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:45 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:45.
# WARNING: Method definition test_on_circle() in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:54 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:54.
# WARNING: Method definition check_poly_segment(Main.poly_segment) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:103 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:103.
# WARNING: Method definition test_tester() in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:350 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\test.jl:350.
