# %%
include("poly_helper.jl")
cont_order = 5;
num_points = 5;
prob = random_poly_prob(num_points,cont_order);
params = PolyParams(cont_order);
sol = poly_smoothing(prob, params)
plot_poly(sol,1);
plot_poly_dim(sol,2,"x");
plot_poly_dim(sol,3,"y");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8416dfd710>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8416aa5e90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8417512c10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f84160bced0>)
