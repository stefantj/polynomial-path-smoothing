# %%
include("poly_helper.jl")

num_points=10
cont_order = 5;
prob = random_poly_prob(num_points,cont_order);                                                                                     
params = PolyParams(cont_order);
sol = poly_smoothing(prob, params)                                                                                                  
plot_poly(sol,1);
plot_poly_dim(sol,2,"x")
plot_poly_dim(sol,3,"y")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f09c1dca1d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f09c1d65dd0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f09bf582090>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f09bf2c1250>)
