# %%
include("poly_helper.jl")
include("VerificationFunction.ipynb")

num_points=10
cont_order = 5;
prob = random_poly_prob(num_points,cont_order);                                                                                     
params = PolyParams(cont_order);
sol = poly_smoothing(prob, params) 
plot_poly(sol,1);
plot_poly_dim(sol,2,"x")
plot_poly_dim(sol,3,"y")
println(verifyActuateablePath(sol, 2.0, 100000000000000.0))
# Out:
# num fixed: 18 num expected: 18
# WARNING: Method definition verifyActuateablePath(Main.PolySol, Float64, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:716 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\VerificationFunction.jl:15
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002570B390>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000029499A58>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000029641940>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000023096BA8>)
# false
# .
