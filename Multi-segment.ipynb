# %%
include("poly_helper.jl")
include("VerificationFunction.jl")

num_points=10
cont_order = 5;
prob = random_poly_prob(num_points,cont_order);                                                                                     
params = PolyParams(cont_order);
sol = poly_smoothing(prob, params) 
plot_poly(sol,1);
plot_poly_dim(sol,2,"x")
plot_poly_dim(sol,3,"y")
println(verifyActuateablePath(sol, 2.0, 100000000000000.0))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000027F75438>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000268F85C0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002662AD30>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002E8F9438>)
# false
# WARNING: Method definition (::Type{Main.PolyProblem})(Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Int64, 1}, Array{Int64, 1}, Array{Float64, 1}, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:5 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:5.
# WARNING: Method definition (::Type{Main.PolyProblem})(Any, Any, Any, Any, Any, Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:5 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:5.
# WARNING: Method definition (::Type{Main.PolyParams})(Int64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:17 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:17.
# WARNING: Method definition (::Type{Main.PolyParams})(Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:17 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:17.
# WARNING: Method definition (::Type{Main.PolySol})(Main.PolyProblem, Main.PolyParams, Int64, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}, Array{Float64, 1}) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:21 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:21.
# WARNING: Method definition (::Type{Main.PolySol})(Any, Any, Any, Any, Any, Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:21 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:21.
# WARNING: Method definition random_poly_prob(Int64, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:35 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:35.
# WARNING: Method definition print_poly_prob(Main.PolyProblem) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:78 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:78.
# WARNING: Method definition plot_poly_dim(Main.PolySol, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:92 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:92.
# WARNING: Method definition plot_poly(Main.PolySol, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:178 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:178.
# WARNING: Method definition form_Q(Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:257 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:257.
# WARNING: Method definition constr_order(Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:283 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:283.
# WARNING: Method definition form_Abig(Main.PolyProblem, Main.PolyParams, Array{Float64, 1}) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:306 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:306.
# WARNING: Method definition form_Qbig(Any, Any, Any, Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:429 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:429.
# WARNING: Method definition poly_smoothing(Main.PolyProblem, Main.PolyParams) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:600 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:600.
# WARNING: Method definition time_multiseg() in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:664 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:664.
# WARNING: Method definition test_multiseg(Any) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:691 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:691.
# WARNING: Method definition verifyActuateablePath(Main.PolySol, Float64, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\VerificationFunction.jl:15 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:713.
# WARNING: Method definition verifyActuateablePath(Main.PolySol, Float64, Float64) in module Main at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\poly_helper.jl:713 overwritten at C:\Users\tmurphy10\Documents\ShieldAi\polynomial-path-smoothing\VerificationFunction.jl:15.
